# %%
import pandas as pd
import numpy as np
import spacy as sp
from spacy.lang.en.stop_words import STOP_WORDS
from spacy.language import Language
import keras_nlp
import pathlib
import random
import tensorflow as tf
from tensorflow import keras
from tensorflow_text.tools.wordpiece_vocab import (
    bert_vocab_from_dataset as bert_vocab,
)

# %%
BATCH_SIZE = 64
EPOCHS = 1  # This should be at least 10 for convergence
MAX_SEQUENCE_LENGTH = 40
ENG_VOCAB_SIZE = 15000
SPA_VOCAB_SIZE = 15000

EMBED_DIM = 256
INTERMEDIATE_DIM = 2048
NUM_HEADS = 8

# %%
data = pd.read_json(r"CS663_Project_Data.json", orient='index')
data = data

# %%
df = data.copy()
df
# Out:
#                                               invocation  \
# 1      Copy loadable kernel module "mymodule.ko" to t...
# 2      Display all lines containing "IP_MROUTE" in th...
# 3      Display current running kernel's compile-time ...
# 4      Find all loadable modules for current kernel, ...
# 5      Look for any instance of "HIGHMEM" in the curr...
# ...                                                  ...
# 10343  using exec in find command to dispaly the sear...
# 10344  verbosely create intermediate directoriy tmp a...
# 10345                       view the manual page of find
# 10346              wait 2 seconds and then print "hello"
# 10347  when using vi-insert keymap bind command "\C-v...
#
#                                                      cmd
# 1      sudo cp mymodule.ko /lib/modules/$(uname -r)/k...
# 2           cat /boot/config-`uname -r` | grep IP_MROUTE
# 3                            cat /boot/config-`uname -r`
# 4           find /lib/modules/`uname -r` -regex .*perf.*
# 5                 grep “HIGHMEM” /boot/config-`uname -r`
# ...                                                  ...
# 10343           find . ... -exec cat {} \; -exec echo \;
# 10344                           mkdir -pv /tmp/boostinst
# 10345                                           man find
# 10346                           echo "hello `sleep 2 &`"
# 10347                bind -m vi-insert '"{" "\C-v{}\ei"'
#
# [10347 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
X = df['inv_tokens']
Y = ["<start> " + cmd + " <end>" for cmd in df['cmd']]
train_x, test_x, train_y, test_y = train_test_split(X, Y, test_size=0.1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'inv_tokens'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-104-32034a318cdb> in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X = df['inv_tokens']
#       3 Y = ["<start> " + cmd + " <end>" for cmd in df['cmd']]
#       4 train_x, test_x, train_y, test_y = train_test_split(X, Y, test_size=0.1)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
# -> 2891                 raise KeyError(key) from err
#    2892
#    2893         if tolerance is not None:
#
# KeyError: 'inv_tokens'

# %%
pairs = []
for i, inv in enumerate(df.invocation.values):
    pair = (inv, df.cmd.values[i])
    pairs.append(pair)

# %%
from spacy.tokens import Doc


nlp = sp.load('en_core_web_sm')

@Language.component('clean_inv')
def clean_inv(doc):
    # Create a new list of filtered tokens
    filtered_tokens = []

    # Iterate over the tokens in the input document
    for token in doc:
        # Check conditions for token filtering
        if (not token.is_punct and not token.is_space and not token.is_digit and
            not token.like_num and not token.is_currency and not token.is_stop):

            # Append the lowercase version of the token's text to the filtered_tokens list
            filtered_tokens.append(token.lower_)

    # Create a new Doc object from the filtered tokens and return it
    return Doc(doc.vocab, words=filtered_tokens)

nlp.add_pipe('clean_inv', name='clean_inv', last=True)

def tokenize_inv(inv):
    doc = nlp(inv)
    tokens = [token.text for token in doc]
    return tokens

# %%
df['inv_tokens'] = df['invocation'].apply(tokenize_inv)
df
# Out:
#                                               invocation  \
# 1      Copy loadable kernel module "mymodule.ko" to t...
# 2      Display all lines containing "IP_MROUTE" in th...
# 3      Display current running kernel's compile-time ...
# 4      Find all loadable modules for current kernel, ...
# 5      Look for any instance of "HIGHMEM" in the curr...
# ...                                                  ...
# 10343  using exec in find command to dispaly the sear...
# 10344  verbosely create intermediate directoriy tmp a...
# 10345                       view the manual page of find
# 10346              wait 2 seconds and then print "hello"
# 10347  when using vi-insert keymap bind command "\C-v...
#
#                                                      cmd  \
# 1      sudo cp mymodule.ko /lib/modules/$(uname -r)/k...
# 2           cat /boot/config-`uname -r` | grep IP_MROUTE
# 3                            cat /boot/config-`uname -r`
# 4           find /lib/modules/`uname -r` -regex .*perf.*
# 5                 grep “HIGHMEM” /boot/config-`uname -r`
# ...                                                  ...
# 10343           find . ... -exec cat {} \; -exec echo \;
# 10344                           mkdir -pv /tmp/boostinst
# 10345                                           man find
# 10346                           echo "hello `sleep 2 &`"
# 10347                bind -m vi-insert '"{" "\C-v{}\ei"'
#
#                                               inv_tokens
# 1      [copy, loadable, kernel, module, mymodule.ko, ...
# 2      [display, lines, containing, ip_mroute, curren...
# 3      [display, current, running, kernel, compile, t...
# 4      [find, loadable, modules, current, kernel, inc...
# 5      [look, instance, highmem, current, kernel, com...
# ...                                                  ...
# 10343    [exec, find, command, dispaly, searched, files]
# 10344  [verbosely, create, intermediate, directoriy, ...
# 10345                         [view, manual, page, find]
# 10346                      [wait, seconds, print, hello]
# 10347  [vi, insert, keymap, bind, command, \c, v{}\ei...
#
# [10347 rows x 3 columns]

# %%
def train_word_piece(text_samples, vocab_size, reserved_tokens):
    word_piece_ds = tf.data.Dataset.from_tensor_slices(text_samples)
    vocab = keras_nlp.tokenizers.compute_word_piece_vocabulary(
        word_piece_ds.batch(1000).prefetch(2),
        vocabulary_size=vocab_size,
        reserved_tokens=reserved_tokens,
    )
    return vocab
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-48-97465694ef84> in <module>
#      21 )
#      22
# ---> 23 inv_vectorization.adapt(np.asarray(train_x))
#      24 cmd_vectorization.adapt(np.asarray(train_y))
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/keras/layers/preprocessing/text_vectorization.py in adapt(self, data, batch_size, steps)
#     470               argument is not supported with array inputs.
#     471         """
# --> 472         super().adapt(data, batch_size=batch_size, steps=steps)
#     473
#     474     def update_state(self, data):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/keras/engine/base_preprocessing_layer.py in adapt(self, data, batch_size, steps)
#     244         if self.built:
#     245             self.reset_state()
# --> 246         data_handler = data_adapter.DataHandler(
#     247             data,
#     248             batch_size=batch_size,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1258
#    1259         adapter_cls = select_data_adapter(x, y)
# -> 1260         self._adapter = adapter_cls(
#    1261             x,
#    1262             y,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     244     ):
#     245         super().__init__(x, y, **kwargs)
# --> 246         x, y, sample_weights = _process_tensorlike((x, y, sample_weights))
#     247         sample_weight_modes = broadcast_sample_weight_modes(
#     248             sample_weights, sample_weight_modes
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/keras/engine/data_adapter.py in _process_tensorlike(inputs)
#    1138         return x
#    1139
# -> 1140     inputs = tf.nest.map_structure(_convert_single_tensor, inputs)
#    1141     return tf.__internal__.nest.list_to_tuple(inputs)
#    1142
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     915
#     916   return pack_sequence_as(
# --> 917       structure[0], [func(*x) for x in entries],
#     918       expand_composites=expand_composites)
#     919
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     915
#     916   return pack_sequence_as(
# --> 917       structure[0], [func(*x) for x in entries],
#     918       expand_composites=expand_composites)
#     919
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/keras/engine/data_adapter.py in _convert_single_tensor(x)
#    1133             if issubclass(x.dtype.type, np.floating):
#    1134                 dtype = backend.floatx()
# -> 1135             return tf.convert_to_tensor(x, dtype=dtype)
#    1136         elif _is_scipy_sparse(x):
#    1137             return _scipy_sparse_to_sparse_tensor(x)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
#     155       del filtered_tb
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     101       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     102   ctx.ensure_initialized()
# --> 103   return ops.EagerTensor(value, ctx.device_name, dtype)
#     104
#     105
#
# ValueError: Failed to convert a NumPy array to a Tensor (Unsupported object type list).
